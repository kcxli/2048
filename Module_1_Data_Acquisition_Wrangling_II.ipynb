# %% [markdown]
# <a href="https://colab.research.google.com/github/kcxli/2048/blob/main/Module_1_Data_Acquisition_Wrangling_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part I of Big Data Analytics - Notebook 2
#
# ## Recall
#
# As we start our journey into Big Data Analytics, the first thing we need to do is **get the data** in the form we need for analysis!  We'll start with an overview of how to acquire and *wrangle* data.
#
# This notebook will be built incrementally to consider several tasks:
#
# * Acquiring data from files and remote sources
# * Information extraction over HTML content
# * A basic "vocabulary" of operators over tables (the relational algebra)
# * Basic manipulation using SQL in DuckDB
#
# * "Data wrangling" or integration:
#   * Cleaning and filtering data, using rules and based operations
#   * Linking data across dataframes or relations
#   * The need for approximate match and record linking
#   * Different techniques
#
# ## Before you start this notebook
#
# Make sure you did the exercises in [Notebook 1](https://colab.research.google.com/github/zackives/upenn-cis5450-hw/blob/main/Module_1_Data_Acquisition.ipynb)!

# %% [markdown]
# ## The Motivating Question
# To illustrate the principles, we focus on the question of **how old company CEOs and founders** (in general, leaders) are.  The question was in part motivated by the following New York Times article:
#
# * Founders of Successful Tech Companies Are Mostly Middle-Aged: https://www.nytimes.com/2019/08/29/business/tech-start-up-founders-nest.html?searchResultPosition=2
#
# So let's test this hypothesis!

# %% [markdown]
# ## Initial Libraries
#
# We'll be using [DuckDB](https://duckdb.org/) as a means of managing our tables.  DuckDB works like a Python library, but manages a full SQL database (in files).  It also integrates very nicely with Pandas, so we'll use it in this course.

# %%
# !pip3 install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %%
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)

# %%
# %%writefile notebook-config.yaml
#
# grader_api_url: 'https://23whrwph9h.execute-api.us-east-1.amazonaws.com/default/Grader23'
# grader_api_key: 'flfkE736fA6Z8GxMDJe2q8Kfk8UDqjsG3GVqOFOa'
# Out:
# Writing notebook-config.yaml

# %%
# !pip3 install penngrader-client
# Out:
# Collecting penngrader-client
#   Downloading penngrader_client-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from penngrader-client) (0.3.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from penngrader-client) (6.0.2)
# Downloading penngrader_client-0.5.2-py3-none-any.whl (10 kB)
# Installing collected packages: penngrader-client
# Successfully installed penngrader-client-0.5.2

# %% [markdown]
# For quiz credit you'll need to update your student ID here!

# %%
#PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO
#TO ASSIGN POINTS TO YOU IN OUR BACKEND
STUDENT_ID = 99999999 # YOUR PENN-ID GOES HERE AS AN INTEGER##PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO

# %% [markdown]
# Quizzes will cumulatively count as HW9... Don't edit this...

# %%
# %set_env HW_ID=cis5450_25f_HW9
# Out:
# env: HW_ID=cis5450_25f_HW9

# %%
import os
from penngrader.grader import *

grader = PennGrader('notebook-config.yaml', os.environ['HW_ID'], STUDENT_ID, STUDENT_ID)
# Out:
# PennGrader initialized with Student ID: 99999999
#
# Make sure this correct or we will not be able to store your grade

# %%
# Imports we'll use through the notebook, collected here for simplicity

# For parsing dates and being able to compare
import datetime

# For fetching remote data
import urllib
import urllib.request

# Pandas dataframes and operations
import pandas as pd

# Numpy matrix and array operations
import numpy as np

# Sqlite is a simplistic database
import duckdb

# Data visualization
import matplotlib

from lxml import etree

# %% [markdown]
# # 1. Reload from HW1
#
# Here is a quick reload of the data from Homework 1.
#
# For simplicity, we reload all of the following:
# * `company_ceos_df` -- Wikipedia list of companies and their CEOs
# * `exec_df` -- crawled executive names and birthdays
# * `company_data_df` -- 7M entries about companies
# * `company_info_df` -- CSV about companies and lines of business

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/companies_sorted.csv
# Out:
# --2025-09-09 04:44:11--  https://storage.googleapis.com/penn-cis5450/companies_sorted.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.181.207, 142.251.184.207, 64.233.179.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.181.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1085578742 (1.0G) [text/csv]
# Saving to: ‘companies_sorted.csv’
#
# companies_sorted.cs 100%[===================>]   1.01G  74.1MB/s    in 10s
#
# 2025-09-09 04:44:21 (102 MB/s) - ‘companies_sorted.csv’ saved [1085578742/1085578742]

# %% [markdown]
# Here's a helper for importing HTML

# %%
import requests
import pandas as pd
from io import StringIO

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

def import_html(url):
  # Let's read an HTML table!
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
  }
  page = requests.get(url, headers=headers).text
  return page

# %%
from io import StringIO

company_ceos_df = pd.read_html(StringIO(import_html('https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs')))[1]

pages = []
page_urls = []

for i, executive in enumerate(company_ceos_df['Executive']):
  url = 'https://en.wikipedia.org/wiki/' + executive.replace(' ', '_')

  page = url.split("/")[-1] #extract the person name at the end of the url

  # An issue: some of the accent characters won't work.  We need to convert them
  # into an HTML URL.  We'll split the URL, then use "parse.quote" to change
  # the structure, then re-form the URL
  url_list = list(urllib.parse.urlsplit(url))
  url_list[2] = urllib.parse.quote(url_list[2])
  url_ascii = urllib.parse.urlunsplit(url_list)
  try:
    response = import_html(url_ascii)
    pages.append(response)
    page_urls.append(url)
  except requests.exceptions.RequestException as e:
    print(e)


# Use lxml.etree.HTML(...) on the HTML content of each page to get a DOM tree that
# can be processed via XPath to extract the bday information.  Store the CEO name,
# webpage, and the birthdate (born) in exec_df.

# We first check that the HTML content has a table of type `vcard`,
# and then extract the `bday` information.  If there is no birthdate, the datetime
# value is NaT (not a type).

rows = []
for i, page in enumerate(pages):
  url = page_urls[i]

  tree = etree.HTML(page)  #create a DOM tree of the page
  bday = tree.xpath('//table[contains(@class,"vcard")]//span[@class="bday"]/text()')
  if len(bday) > 0:
      name = url[url.rfind('/')+1:] # The part of the URL after the last /
      rows.append({'name': name, 'page': url,
                  'born': datetime.datetime.strptime(bday[0], '%Y-%m-%d')})
  else:
          rows.append({'name': url[url.rfind('/')+1:], 'page': url
                                    , 'born': np.datetime64('NaT')})

exec_df = pd.DataFrame(rows)
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))
company_data_df = pd.read_csv('companies_sorted.csv')
countries_df = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")

data = urllib.request.urlopen(\
       'https://gist.github.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv')

company_info_df = pd.read_csv(data)

# %% [markdown]
# Now let's use DuckDB to allow working with on-disk and in memory data.

# %%
con = duckdb.connect('local.db')
con.sql("""CREATE TABLE IF NOT EXISTS company_data AS
           SELECT *
           FROM company_data_df""")
con.sql("""create table if not exists company_ceos as select * from company_ceos_df""")
con.sql("""create table if not exists executives as select * from exec_df""")

# query the table
con.table("company_data").show()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌────────────┬────────────────────────────────────────────────┬────────────────────┬──────────────┬─────────────────────────────────────┬─────────────┬────────────────────────────────────────┬────────────────┬─────────────────────────────────────────────────────────────────┬───────────────────────────┬─────────────────────────┐
# │ Unnamed: 0 │                      name                      │       domain       │ year founded │              industry               │ size range  │                locality                │    country     │                          linkedin url                           │ current employee estimate │ total employee estimate │
# │   int64    │                    varchar                     │      varchar       │    double    │               varchar               │   varchar   │                varchar                 │    varchar     │                             varchar                             │           int64           │          int64          │
# ├────────────┼────────────────────────────────────────────────┼────────────────────┼──────────────┼─────────────────────────────────────┼─────────────┼────────────────────────────────────────┼────────────────┼─────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────────────────────┤
# │    5872184 │ ibm                                            │ ibm.com            │       1911.0 │ information technology and services │ 10001+      │ new york, new york, united states      │ united states  │ linkedin.com/company/ibm                                        │                    274047 │                  716906 │
# │    4425416 │ tata consultancy services                      │ tcs.com            │       1968.0 │ information technology and services │ 10001+      │ bombay, maharashtra, india             │ india          │ linkedin.com/company/tata-consultancy-services                  │                    190771 │                  341369 │
# │      21074 │ accenture                                      │ accenture.com      │       1989.0 │ information technology and services │ 10001+      │ dublin, dublin, ireland                │ ireland        │ linkedin.com/company/accenture                                  │                    190689 │                  455768 │
# │    2309813 │ us army                                        │ goarmy.com         │       1800.0 │ military                            │ 10001+      │ alexandria, virginia, united states    │ united states  │ linkedin.com/company/us-army                                    │                    162163 │                  445958 │
# │    1558607 │ ey                                             │ ey.com             │       1989.0 │ accounting                          │ 10001+      │ london, greater london, united kingdom │ united kingdom │ linkedin.com/company/ernstandyoung                              │                    158363 │                  428960 │
# │    3844889 │ hewlett-packard                                │ hpe.com            │       1939.0 │ information technology and services │ 10001+      │ palo alto, california, united states   │ united states  │ linkedin.com/company/hewlett-packard-enterprise                 │                    127952 │                  412952 │
# │    2959148 │ cognizant technology solutions                 │ cognizant.com      │       1994.0 │ information technology and services │ 10001+      │ teaneck, new jersey, united states     │ united states  │ linkedin.com/company/cognizant                                  │                    122031 │                  210020 │
# │    5944912 │ walmart                                        │ walmartcareers.com │       1962.0 │ retail                              │ 10001+      │ withee, wisconsin, united states       │ united states  │ linkedin.com/company/walmart                                    │                    120753 │                  272827 │
# │    3727010 │ microsoft                                      │ microsoft.com      │       1975.0 │ computer software                   │ 10001+      │ redmond, washington, united states     │ united states  │ linkedin.com/company/microsoft                                  │                    116196 │                  276983 │
# │    3300741 │ at&t                                           │ att.com            │       1876.0 │ telecommunications                  │ 10001+      │ dallas, texas, united states           │ united states  │ linkedin.com/company/at&t                                       │                    115188 │                  269659 │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │    4782764 │ jönköpings kommun                              │ jonkoping.se       │         NULL │ government administration           │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/j-nk-pings-kommun                          │                      1118 │                    1964 │
# │    3432133 │ jmc projects india ltd                         │ jmcprojects.com    │       1982.0 │ human resources                     │ 1001 - 5000 │ bombay, maharashtra, india             │ india          │ linkedin.com/company/jmc-projects-india-ltd                     │                      1118 │                    2112 │
# │     910050 │ öbb                                            │ oebb.at            │         NULL │ transportation/trucking/railroad    │ 1001 - 5000 │ wien, vienna, austria                  │ austria        │ linkedin.com/company/obb                                        │                      1118 │                    1546 │
# │    6444131 │ vaillant group                                 │ vaillant-group.com │       1874.0 │ renewables & environment            │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/vaillant                                   │                      1118 │                    2540 │
# │     916799 │ embracon administradora de consórcio ltda.     │ embracon.com.br    │       1988.0 │ financial services                  │ 1001 - 5000 │ santana de parnaíba, sao paulo, brazil │ brazil         │ linkedin.com/company/embracon-administradora-de-cons-rcio-ltda. │                      1118 │                    2240 │
# │    3585785 │ university of chicago booth school of business │ chicagobooth.edu   │       1898.0 │ higher education                    │ 1001 - 5000 │ chicago, illinois, united states       │ united states  │ linkedin.com/company/universityofchicagoboothschoolofbusiness   │                      1118 │                    3220 │
# │    2583172 │ pantaloon retail india ltd                     │ NULL               │         NULL │ retail                              │ 1001 - 5000 │ bombay, maharashtra, india             │ india          │ linkedin.com/company/pantaloon-retail-india-ltd                 │                      1118 │                    4723 │
# │    1406043 │ nv energy                                      │ nvenergy.com       │       1906.0 │ utilities                           │ 1001 - 5000 │ las vegas, nevada, united states       │ united states  │ linkedin.com/company/nv-energy                                  │                      1118 │                    1834 │
# │     955441 │ mining                                         │ muslimbase.com     │         NULL │ mining & metals                     │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/mining                                     │                      1118 │                    1421 │
# │    5571765 │ university of stirling                         │ stir.ac.uk         │       1967.0 │ higher education                    │ 1001 - 5000 │ stirling, stirling, united kingdom     │ united kingdom │ linkedin.com/company/university-of-stirling                     │                      1118 │                    2680 │
# ├────────────┴────────────────────────────────────────────────┴────────────────────┴──────────────┴─────────────────────────────────────┴─────────────┴────────────────────────────────────────┴────────────────┴─────────────────────────────────────────────────────────────────┴───────────────────────────┴─────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                              11 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # 2.0 Data Transformation and Querying
#
# Looking at our data to clean via *projection*...
#
# Generally, we can extract one "narrower" table form another by using **double brackets**.

# %%
# Let's take a look at the data.  Here's a way of PROJECTING the exec_df dataframe into
# a smaller table

exec_df[['name', 'born']]
# Out:
#                      name                 born
# 0             Julie_Sweet                  NaT
# 1    Kumar_Mangalam_Birla  1967-06-14 00:00:00
# 2        Shantanu_Narayen  1963-05-27 00:00:00
# 3         Guillaume_Faury  1968-02-22 00:00:00
# 4                Eddie_Wu                  NaT
# ..                    ...                  ...
# 133           Ann_Sarnoff                  NaT
# 134           Jason_Kilar  1971-04-26 00:00:00
# 135        Charles_Scharf  1965-04-24 00:00:00
# 136           John_Mackey                  NaT
# 137           Rich_Barton                  NaT
#
# [138 rows x 2 columns]

# %%
# In SQL it's SELECT with the fields FROM the table
con.sql('select name, born from executives')
# Out:
# ┌──────────────────────┬─────────────────────┐
# │         name         │        born         │
# │       varchar        │      timestamp      │
# ├──────────────────────┼─────────────────────┤
# │ Julie_Sweet          │ NULL                │
# │ Kumar_Mangalam_Birla │ 1967-06-14 00:00:00 │
# │ Shantanu_Narayen     │ 1963-05-27 00:00:00 │
# │ Guillaume_Faury      │ 1968-02-22 00:00:00 │
# │ Eddie_Wu             │ NULL                │
# │ Andy_Jassy           │ 1968-01-13 00:00:00 │
# │ Lisa_Su              │ NULL                │
# │ Stephen_Squeri       │ NULL                │
# │ Joseph_R._Swedish    │ 1951-05-17 00:00:00 │
# │ Tim_Cook             │ 1960-11-01 00:00:00 │
# │    ·                 │          ·          │
# │    ·                 │          ·          │
# │    ·                 │          ·          │
# │ Vittorio_Colao       │ 1961-10-03 00:00:00 │
# │ Herbert_Diess        │ 1958-10-24 00:00:00 │
# │ Robert_Iger          │ 1951-02-10 00:00:00 │
# │ Stefano_Pessina      │ 1941-06-04 00:00:00 │
# │ Doug_McMillon        │ 1966-10-17 00:00:00 │
# │ Ann_Sarnoff          │ NULL                │
# │ Jason_Kilar          │ 1971-04-26 00:00:00 │
# │ Charles_Scharf       │ 1965-04-24 00:00:00 │
# │ John_Mackey          │ NULL                │
# │ Rich_Barton          │ NULL                │
# ├──────────────────────┴─────────────────────┤
# │ 138 rows (20 shown)              2 columns │
# └────────────────────────────────────────────┘

# %%
# If I use single brackets, I can extract a single column as a Series.
exec_df['name']
# Out:
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3           Guillaume_Faury
# 4                  Eddie_Wu
#                ...
# 133             Ann_Sarnoff
# 134             Jason_Kilar
# 135          Charles_Scharf
# 136             John_Mackey
# 137             Rich_Barton
# Name: name, Length: 138, dtype: object

# %%
# We can use SQL over the dataframe OR here
duckdb.sql('SELECT name FROM exec_df')
# Out:
# ┌──────────────────────┐
# │         name         │
# │       varchar        │
# ├──────────────────────┤
# │ Julie_Sweet          │
# │ Kumar_Mangalam_Birla │
# │ Shantanu_Narayen     │
# │ Guillaume_Faury      │
# │ Eddie_Wu             │
# │ Andy_Jassy           │
# │ Lisa_Su              │
# │ Stephen_Squeri       │
# │ Joseph_R._Swedish    │
# │ Tim_Cook             │
# │    ·                 │
# │    ·                 │
# │    ·                 │
# │ Vittorio_Colao       │
# │ Herbert_Diess        │
# │ Robert_Iger          │
# │ Stefano_Pessina      │
# │ Doug_McMillon        │
# │ Ann_Sarnoff          │
# │ Jason_Kilar          │
# │ Charles_Scharf       │
# │ John_Mackey          │
# │ Rich_Barton          │
# ├──────────────────────┤
# │ 138 rows (20 shown)  │
# └──────────────────────┘

# %%
# Notice anything awry?

for person in exec_df['name']:
    print (person)
# Out:
# Julie_Sweet
# Kumar_Mangalam_Birla
# Shantanu_Narayen
# Guillaume_Faury
# Eddie_Wu
# Andy_Jassy
# Lisa_Su
# Stephen_Squeri
# Joseph_R._Swedish
# Tim_Cook
# Aditya_Mittal
# John_Stankey
# Charles_Woodburn
# Tapan_Singhel
# Carlos_Torres_Vila
# Brian_Moynihan
# C.S._Venkatakrishnan
# Warren_Buffett
# Hubert_Joly
# Sunil_Bharti_Mittal
# Stephen_A._Schwarzman
# Mike_Henry
# Oliver_Zipse
# Kelly_Ortberg
# Rich_Lesser
# Bob_Dudley
# Hock_Tan
# Denise_Morrison
# Mark_Shuttleworth
# Richard_Fairbank
# Jim_Umpleby
# Evan_Greenberg
# Chuck_Robbins
# Jane_Fraser
# James_Quincey
# Michael_J._Cavanagh
# Thomas_Gottstein
# Ola_Källenius
# Michael_Dell
# Ed_Bastian
# Christian_Sewing
# Tobias_Meyer
# Edward_D._Breen
# Devin_Wenig
# Börje_Ekholm
# Darren_Woods
# Carmine_Di_Sibio
# Mark_Zuckerberg
# Raj_Subramaniam
# Sergio_Marchionne
# Abigail_Johnson
# James_Hackett
# Terry_Gou
# Lachlan_Murdoch
# Ryan_Cohen
# Phebe_Novakovic
# H._Lawrence_Culp_Jr.
# Mary_T._Barra
# Emma_Walmsley
# David_M._Solomon
# Sundar_Pichai
# C_Vijayakumar
# Antonio_Neri
# Darius_Adamczyk
# Noel_Quinn
# Arvind_Krishna
# Salil_Parekh
# Lip-Bu_Tan
# James_Dimon
# Pieter_Elbers
# Charles_G._Koch
# Marillyn_Hewson
# Steve_Rowe
# Chris_Kempczinski
# Bob_Sternfels
# Steven_A._Kandarian
# Isaac_Larian
# Satya_Nadella
# James_P._Gorman
# Michael_J._Cavanagh
# Robert_James_Thomson
# Mark_Thompson
# Mark_Parker
# Pekka_Lundmark
# Vasant_Narasimhan
# Tatsumi_Kimishima
# Safra_Catz
# Ramon_Laguarta
# Albert_Bourla
# David_S._Taylor
# John_Strangfeld
# John_Mullen
# Anil_Ambani
# Mukesh_Ambani
# Luca_de_Meo
# David_I._McKay
# Ross_McEwan
# Wael_Sawan
# Michael_O'Leary
# Douglas_L._Peterson
# Oh-Hyun_Kwon
# Christian_Klein
# Herbert_Fisk_Johnson_III
# Jean-Pascal_Tricoire
# Peter_Harrison
# Chua_Sock_Koong
# Masayoshi_Son
# Tony_Aquila
# Elon_Musk
# Robert_E._Jordan
# J._Clifford_Hudson
# Brian_Niccol
# Raymond_Kwok
# William_H._Rogers_Jr.
# Brian_Cornell
# Rajesh_Gopinathan
# Li_Dongsheng
# Andy_Penn
# Dave_Lewis
# Elon_Musk
# Alan_D._Schnitzer
# Akio_Toyoda
# Scott_Kirby
# Brian_Thompson
# Ralph_Hamers
# Hans_Vestberg
# Robert_Bakish
# Ryan_McInerney
# Vittorio_Colao
# Herbert_Diess
# Robert_Iger
# Stefano_Pessina
# Doug_McMillon
# Ann_Sarnoff
# Jason_Kilar
# Charles_Scharf
# John_Mackey
# Rich_Barton

# %%
def to_space(x):
  return x.replace('_', ' ')

# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(to_space)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 133             Ann Sarnoff
# 134             Jason Kilar
# 135          Charles Scharf
# 136             John Mackey
# 137             Rich Barton
# Name: name, Length: 138, dtype: object

# %%
# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(lambda x: x.replace('_', ' '))
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 133             Ann Sarnoff
# 134             Jason Kilar
# 135          Charles Scharf
# 136             John Mackey
# 137             Rich Barton
# Name: name, Length: 138, dtype: object

# %%
# I can also use *apply* to call a function over the rows of a dataframe
exec_df.apply(lambda x: x['name'].replace('_', ' '), axis=1)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 133             Ann Sarnoff
# 134             Jason Kilar
# 135          Charles Scharf
# 136             John Mackey
# 137             Rich Barton
# Length: 138, dtype: object

# %%
# Let's clean the name by removing underscores...
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))

exec_df
# Out:
#                      name                                               page  \
# 0             Julie_Sweet          https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_B...
# 2        Shantanu_Narayen     https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury      https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu             https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                ...
# 133           Ann_Sarnoff          https://en.wikipedia.org/wiki/Ann_Sarnoff
# 134           Jason_Kilar          https://en.wikipedia.org/wiki/Jason_Kilar
# 135        Charles_Scharf       https://en.wikipedia.org/wiki/Charles_Scharf
# 136           John_Mackey          https://en.wikipedia.org/wiki/John_Mackey
# 137           Rich_Barton          https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 133                  NaT           Ann Sarnoff
# 134  1971-04-26 00:00:00           Jason Kilar
# 135  1965-04-24 00:00:00        Charles Scharf
# 136                  NaT           John Mackey
# 137                  NaT           Rich Barton
#
# [138 rows x 4 columns]

# %%
exec_df.rename(columns={'name': 'old_name'})
# Out:
#                  old_name                                               page  \
# 0             Julie_Sweet          https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_B...
# 2        Shantanu_Narayen     https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury      https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu             https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                ...
# 133           Ann_Sarnoff          https://en.wikipedia.org/wiki/Ann_Sarnoff
# 134           Jason_Kilar          https://en.wikipedia.org/wiki/Jason_Kilar
# 135        Charles_Scharf       https://en.wikipedia.org/wiki/Charles_Scharf
# 136           John_Mackey          https://en.wikipedia.org/wiki/John_Mackey
# 137           Rich_Barton          https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 133                  NaT           Ann Sarnoff
# 134  1971-04-26 00:00:00           Jason Kilar
# 135  1965-04-24 00:00:00        Charles Scharf
# 136                  NaT           John Mackey
# 137                  NaT           Rich Barton
#
# [138 rows x 4 columns]

# %%
# We can do the same via SQL.

duckdb.sql("""SELECT name, replace(name, '_', ' ') AS clean_name
              FROM exec_df""")
# Out:
# ┌──────────────────────┬──────────────────────┐
# │         name         │      clean_name      │
# │       varchar        │       varchar        │
# ├──────────────────────┼──────────────────────┤
# │ Julie_Sweet          │ Julie Sweet          │
# │ Kumar_Mangalam_Birla │ Kumar Mangalam Birla │
# │ Shantanu_Narayen     │ Shantanu Narayen     │
# │ Guillaume_Faury      │ Guillaume Faury      │
# │ Eddie_Wu             │ Eddie Wu             │
# │ Andy_Jassy           │ Andy Jassy           │
# │ Lisa_Su              │ Lisa Su              │
# │ Stephen_Squeri       │ Stephen Squeri       │
# │ Joseph_R._Swedish    │ Joseph R. Swedish    │
# │ Tim_Cook             │ Tim Cook             │
# │    ·                 │    ·                 │
# │    ·                 │    ·                 │
# │    ·                 │    ·                 │
# │ Vittorio_Colao       │ Vittorio Colao       │
# │ Herbert_Diess        │ Herbert Diess        │
# │ Robert_Iger          │ Robert Iger          │
# │ Stefano_Pessina      │ Stefano Pessina      │
# │ Doug_McMillon        │ Doug McMillon        │
# │ Ann_Sarnoff          │ Ann Sarnoff          │
# │ Jason_Kilar          │ Jason Kilar          │
# │ Charles_Scharf       │ Charles Scharf       │
# │ John_Mackey          │ John Mackey          │
# │ Rich_Barton          │ Rich Barton          │
# ├──────────────────────┴──────────────────────┤
# │ 138 rows (20 shown)               2 columns │
# └─────────────────────────────────────────────┘

# %% [markdown]
# ## 2.1. Selecting a subset of the rows

# %%
# Here's a column

exec_df['clean_name']
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 133             Ann Sarnoff
# 134             Jason Kilar
# 135          Charles Scharf
# 136             John Mackey
# 137             Rich Barton
# Name: clean_name, Length: 138, dtype: object

# %%
# We can apply a test (predicate) to each column, returning a Series of boolean true/false values

exec_df['clean_name'] == 'Julie Sweet'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# Name: clean_name, Length: 138, dtype: bool

# %%
# If we compose these, we'll get only those rows where the boolean condition was True

exec_df[exec_df['clean_name'] == 'Julie Sweet']
# Out:
#           name                                       page born   clean_name
# 0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT  Julie Sweet

# %% [markdown]
# SQL lets us use any case, but convention is to capitalize the SQL keywords such as `SELECT`, `FROM`, `WHERE` to aid in readability.  Also, we should use single-quotes for SQL strings, so we'll typically pass the SQL command in with double-quotes.

# %%
duckdb.sql("SELECT * FROM exec_df WHERE clean_name='Julie Sweet'")
# Out:
# ┌─────────────┬───────────────────────────────────────────┬───────────┬─────────────┐
# │    name     │                   page                    │   born    │ clean_name  │
# │   varchar   │                  varchar                  │ timestamp │   varchar   │
# ├─────────────┼───────────────────────────────────────────┼───────────┼─────────────┤
# │ Julie_Sweet │ https://en.wikipedia.org/wiki/Julie_Sweet │ NULL      │ Julie Sweet │
# └─────────────┴───────────────────────────────────────────┴───────────┴─────────────┘

# %%
exec_df[exec_df['clean_name'] == 'Julie Sweet'][['page']]
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %% [markdown]
# Here we'll use the triple-quote syntax for Python strings, which allows us to pass a multi-line string to SQL...

# %%
duckdb.sql("""SELECT clean_name
            FROM exec_df
            WHERE clean_name='Julie Sweet'""")
# Out:
# ┌─────────────┐
# │ clean_name  │
# │   varchar   │
# ├─────────────┤
# │ Julie Sweet │
# └─────────────┘

# %%
import numpy as np

exec_df.dropna(subset=['born'])
# Out:
#                      name                                               page  \
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_B...
# 2        Shantanu_Narayen     https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury      https://en.wikipedia.org/wiki/Guillaume_Faury
# 5              Andy_Jassy           https://en.wikipedia.org/wiki/Andy_Jassy
# 8       Joseph_R._Swedish    https://en.wikipedia.org/wiki/Joseph_R._Swedish
# ..                    ...                                                ...
# 130           Robert_Iger          https://en.wikipedia.org/wiki/Robert_Iger
# 131       Stefano_Pessina      https://en.wikipedia.org/wiki/Stefano_Pessina
# 132         Doug_McMillon        https://en.wikipedia.org/wiki/Doug_McMillon
# 134           Jason_Kilar          https://en.wikipedia.org/wiki/Jason_Kilar
# 135        Charles_Scharf       https://en.wikipedia.org/wiki/Charles_Scharf
#
#                     born            clean_name
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 5    1968-01-13 00:00:00            Andy Jassy
# 8    1951-05-17 00:00:00     Joseph R. Swedish
# ..                   ...                   ...
# 130  1951-02-10 00:00:00           Robert Iger
# 131  1941-06-04 00:00:00       Stefano Pessina
# 132  1966-10-17 00:00:00         Doug McMillon
# 134  1971-04-26 00:00:00           Jason Kilar
# 135  1965-04-24 00:00:00        Charles Scharf
#
# [79 rows x 4 columns]

# %%
duckdb.sql("""SELECT *
            FROM exec_df
            WHERE born IS NOT NULL""")
# Out:
# ┌──────────────────────┬────────────────────────────────────────────────────┬─────────────────────┬──────────────────────┐
# │         name         │                        page                        │        born         │      clean_name      │
# │       varchar        │                      varchar                       │      timestamp      │       varchar        │
# ├──────────────────────┼────────────────────────────────────────────────────┼─────────────────────┼──────────────────────┤
# │ Kumar_Mangalam_Birla │ https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla │ 1967-06-14 00:00:00 │ Kumar Mangalam Birla │
# │ Shantanu_Narayen     │ https://en.wikipedia.org/wiki/Shantanu_Narayen     │ 1963-05-27 00:00:00 │ Shantanu Narayen     │
# │ Guillaume_Faury      │ https://en.wikipedia.org/wiki/Guillaume_Faury      │ 1968-02-22 00:00:00 │ Guillaume Faury      │
# │ Andy_Jassy           │ https://en.wikipedia.org/wiki/Andy_Jassy           │ 1968-01-13 00:00:00 │ Andy Jassy           │
# │ Joseph_R._Swedish    │ https://en.wikipedia.org/wiki/Joseph_R._Swedish    │ 1951-05-17 00:00:00 │ Joseph R. Swedish    │
# │ Tim_Cook             │ https://en.wikipedia.org/wiki/Tim_Cook             │ 1960-11-01 00:00:00 │ Tim Cook             │
# │ Aditya_Mittal        │ https://en.wikipedia.org/wiki/Aditya_Mittal        │ 1976-01-22 00:00:00 │ Aditya Mittal        │
# │ Charles_Woodburn     │ https://en.wikipedia.org/wiki/Charles_Woodburn     │ 1971-03-11 00:00:00 │ Charles Woodburn     │
# │ Tapan_Singhel        │ https://en.wikipedia.org/wiki/Tapan_Singhel        │ 1966-08-12 00:00:00 │ Tapan Singhel        │
# │ Warren_Buffett       │ https://en.wikipedia.org/wiki/Warren_Buffett       │ 1930-08-30 00:00:00 │ Warren Buffett       │
# │      ·               │                     ·                              │          ·          │      ·               │
# │      ·               │                     ·                              │          ·          │      ·               │
# │      ·               │                     ·                              │          ·          │      ·               │
# │ Ralph_Hamers         │ https://en.wikipedia.org/wiki/Ralph_Hamers         │ 1966-05-25 00:00:00 │ Ralph Hamers         │
# │ Hans_Vestberg        │ https://en.wikipedia.org/wiki/Hans_Vestberg        │ 1965-06-23 00:00:00 │ Hans Vestberg        │
# │ Robert_Bakish        │ https://en.wikipedia.org/wiki/Robert_Bakish        │ 1963-12-14 00:00:00 │ Robert Bakish        │
# │ Vittorio_Colao       │ https://en.wikipedia.org/wiki/Vittorio_Colao       │ 1961-10-03 00:00:00 │ Vittorio Colao       │
# │ Herbert_Diess        │ https://en.wikipedia.org/wiki/Herbert_Diess        │ 1958-10-24 00:00:00 │ Herbert Diess        │
# │ Robert_Iger          │ https://en.wikipedia.org/wiki/Robert_Iger          │ 1951-02-10 00:00:00 │ Robert Iger          │
# │ Stefano_Pessina      │ https://en.wikipedia.org/wiki/Stefano_Pessina      │ 1941-06-04 00:00:00 │ Stefano Pessina      │
# │ Doug_McMillon        │ https://en.wikipedia.org/wiki/Doug_McMillon        │ 1966-10-17 00:00:00 │ Doug McMillon        │
# │ Jason_Kilar          │ https://en.wikipedia.org/wiki/Jason_Kilar          │ 1971-04-26 00:00:00 │ Jason Kilar          │
# │ Charles_Scharf       │ https://en.wikipedia.org/wiki/Charles_Scharf       │ 1965-04-24 00:00:00 │ Charles Scharf       │
# ├──────────────────────┴────────────────────────────────────────────────────┴─────────────────────┴──────────────────────┤
# │ 79 rows (20 shown)                                                                                           4 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 2.2. Joining Data
#
# We start with a simple join between company_ceos_df and exec_df and persist it to the database.  We then check how many companies did not have a match on CEO name.

# %%
exec_df[['clean_name', 'born']]
# Out:
#                clean_name                 born
# 0             Julie Sweet                  NaT
# 1    Kumar Mangalam Birla  1967-06-14 00:00:00
# 2        Shantanu Narayen  1963-05-27 00:00:00
# 3         Guillaume Faury  1968-02-22 00:00:00
# 4                Eddie Wu                  NaT
# ..                    ...                  ...
# 133           Ann Sarnoff                  NaT
# 134           Jason Kilar  1971-04-26 00:00:00
# 135        Charles Scharf  1965-04-24 00:00:00
# 136           John Mackey                  NaT
# 137           Rich Barton                  NaT
#
# [138 rows x 2 columns]

# %%
# Remove any duplicate executive entries

exec_df = exec_df.drop_duplicates()

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                 Executive             Company
# 0             Julie Sweet           Accenture
# 1    Kumar Mangalam Birla  Aditya Birla Group
# 2        Shantanu Narayen       Adobe Systems
# 3         Guillaume Faury              Airbus
# 4                Eddie Wu             Alibaba
# ..                    ...                 ...
# 133           Ann Sarnoff     Warner Brothers
# 134           Jason Kilar         WarnerMedia
# 135        Charles Scharf         Wells Fargo
# 136           John Mackey  Whole Foods Market
# 137           Rich Barton        Zillow Group
#
# [138 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'])
# Out:
#                 Executive             Company            clean_name  \
# 0             Julie Sweet           Accenture           Julie Sweet
# 1    Kumar Mangalam Birla  Aditya Birla Group  Kumar Mangalam Birla
# 2        Shantanu Narayen       Adobe Systems      Shantanu Narayen
# 3         Guillaume Faury              Airbus       Guillaume Faury
# 4                Eddie Wu             Alibaba              Eddie Wu
# ..                    ...                 ...                   ...
# 133           Ann Sarnoff     Warner Brothers           Ann Sarnoff
# 134           Jason Kilar         WarnerMedia           Jason Kilar
# 135        Charles Scharf         Wells Fargo        Charles Scharf
# 136           John Mackey  Whole Foods Market           John Mackey
# 137           Rich Barton        Zillow Group           Rich Barton
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1968-02-22 00:00:00
# 4                    NaT
# ..                   ...
# 133                  NaT
# 134  1971-04-26 00:00:00
# 135  1965-04-24 00:00:00
# 136                  NaT
# 137                  NaT
#
# [138 rows x 4 columns]

# %% [markdown]
# We can `JOIN ON` in the `FROM` clause.

# %%
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df JOIN exec_df ON Executive=clean_name
          """)
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Julie Sweet          │ Accenture                │ NULL                │
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems            │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Eddie Wu             │ Alibaba                  │ NULL                │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ NULL                │
# │ Stephen Squeri       │ American Express         │ NULL                │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Herbert Diess        │ Volkswagen Group         │ 1958-10-24 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Ann Sarnoff          │ Warner Brothers          │ NULL                │
# │ Jason Kilar          │ WarnerMedia              │ 1971-04-26 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ John Mackey          │ Whole Foods Market       │ NULL                │
# │ Rich Barton          │ Zillow Group             │ NULL                │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 138 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Note there is another way you'll sometimes see, in older versions of SQL... Which is to put the join as a `WHERE` condition:

# %%
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df, exec_df
            WHERE Executive=clean_name
          """)
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Julie Sweet          │ Accenture                │ NULL                │
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems            │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Eddie Wu             │ Alibaba                  │ NULL                │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ NULL                │
# │ Stephen Squeri       │ American Express         │ NULL                │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Herbert Diess        │ Volkswagen Group         │ 1958-10-24 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Ann Sarnoff          │ Warner Brothers          │ NULL                │
# │ Jason Kilar          │ WarnerMedia              │ 1971-04-26 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ John Mackey          │ Whole Foods Market       │ NULL                │
# │ Rich Barton          │ Zillow Group             │ NULL                │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 138 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# OK, let's drop the cases where we don't have a CEO's birthday: these aren't useful!

# %%
# Shall we skip the cases where we don't have the birthday?
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df JOIN exec_df ON Executive=clean_name
            WHERE born is not null
          """)
# Out:
# ┌──────────────────────┬─────────────────────────────────┬─────────────────────┐
# │      Executive       │             Company             │        born         │
# │       varchar        │             varchar             │      timestamp      │
# ├──────────────────────┼─────────────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group              │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems                   │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                          │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                          │ 1968-01-13 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                          │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                           │ 1960-11-01 00:00:00 │
# │ Aditya Mittal        │ Arcelor Mittal                  │ 1976-01-22 00:00:00 │
# │ Charles Woodburn     │ BAE Systems                     │ 1971-03-11 00:00:00 │
# │ Tapan Singhel        │ Bajaj Allianz General Insurance │ 1966-08-12 00:00:00 │
# │ Warren Buffett       │ Berkshire Hathaway              │ 1930-08-30 00:00:00 │
# │      ·               │  ·                              │          ·          │
# │      ·               │  ·                              │          ·          │
# │      ·               │  ·                              │          ·          │
# │ Ralph Hamers         │ UBS                             │ 1966-05-25 00:00:00 │
# │ Hans Vestberg        │ Verizon Communications          │ 1965-06-23 00:00:00 │
# │ Robert Bakish        │ ViacomCBS                       │ 1963-12-14 00:00:00 │
# │ Vittorio Colao       │ Vodafone                        │ 1961-10-03 00:00:00 │
# │ Herbert Diess        │ Volkswagen Group                │ 1958-10-24 00:00:00 │
# │ Robert Iger          │ Walt Disney Company             │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance        │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                         │ 1966-10-17 00:00:00 │
# │ Jason Kilar          │ WarnerMedia                     │ 1971-04-26 00:00:00 │
# │ Charles Scharf       │ Wells Fargo                     │ 1965-04-24 00:00:00 │
# ├──────────────────────┴─────────────────────────────────┴─────────────────────┤
# │ 79 rows (20 shown)                                                 3 columns │
# └──────────────────────────────────────────────────────────────────────────────┘

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                 Executive             Company
# 0             Julie Sweet           Accenture
# 1    Kumar Mangalam Birla  Aditya Birla Group
# 2        Shantanu Narayen       Adobe Systems
# 3         Guillaume Faury              Airbus
# 4                Eddie Wu             Alibaba
# ..                    ...                 ...
# 133           Ann Sarnoff     Warner Brothers
# 134           Jason Kilar         WarnerMedia
# 135        Charles Scharf         Wells Fargo
# 136           John Mackey  Whole Foods Market
# 137           Rich Barton        Zillow Group
#
# [138 rows x 2 columns]

# %%
exec_df[['clean_name', 'born']]
# Out:
#                clean_name                 born
# 0             Julie Sweet                  NaT
# 1    Kumar Mangalam Birla  1967-06-14 00:00:00
# 2        Shantanu Narayen  1963-05-27 00:00:00
# 3         Guillaume Faury  1968-02-22 00:00:00
# 4                Eddie Wu                  NaT
# ..                    ...                  ...
# 133           Ann Sarnoff                  NaT
# 134           Jason Kilar  1971-04-26 00:00:00
# 135        Charles Scharf  1965-04-24 00:00:00
# 136           John Mackey                  NaT
# 137           Rich Barton                  NaT
#
# [136 rows x 2 columns]

# %% [markdown]
# ## 2.4. Finding the misses in the join with OUTER JOINs.
#
# Note that the join above resulted in 174 rows.  However, there are more rows in company_ceos_df so we are missing some companies.  We can see which are missed using a LEFT OUTERJOIN (aka LEFT JOIN); setting "indicator= True" allows us to see which tuples in company_ceos_df failed to find a match (left_only, e.g. row 24 and 172).

# %%
pd.set_option('display.max_rows', 200)
display(company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="left", indicator=True))
# Out:
#                     Executive                          Company  \
# 0                 Julie Sweet                        Accenture
# 1        Kumar Mangalam Birla               Aditya Birla Group
# 2            Shantanu Narayen                    Adobe Systems
# 3             Guillaume Faury                           Airbus
# 4                    Eddie Wu                          Alibaba
# 5                  Andy Jassy                           Amazon
# 6                     Lisa Su           Advanced Micro Devices
# 7              Stephen Squeri                 American Express
# 8           Joseph R. Swedish                           Anthem
# 9                    Tim Cook                            Apple
# 10              Aditya Mittal                   Arcelor Mittal
# 11               John Stankey                             AT&T
# 12           Charles Woodburn                      BAE Systems
# 13              Tapan Singhel  Bajaj Allianz General Insurance
# 14         Carlos Torres Vila  Banco Bilbao Vizcaya Argentaria
# 15             Brian Moynihan                  Bank of America
# 16       C.S. Venkatakrishnan                         Barclays
# 17             Warren Buffett               Berkshire Hathaway
# 18                Hubert Joly                         Best Buy
# 19        Sunil Bharti Mittal               Bharti Enterprises
# 20      Stephen A. Schwarzman                 Blackstone Group
# 21                 Mike Henry                              BHP
# 22               Oliver Zipse                              BMW
# 23              Kelly Ortberg                           Boeing
# 24                Rich Lesser          Boston Consulting Group
# 25                 Bob Dudley                               BP
# 26                   Hock Tan                         Broadcom
# 27            Denise Morrison            Campbell Soup Company
# 28          Mark Shuttleworth                        Canonical
# 29           Richard Fairbank            Capital One Financial
# 30                Jim Umpleby                      Caterpillar
# 31             Evan Greenberg                            Chubb
# 32              Chuck Robbins                    Cisco Systems
# 33                Jane Fraser                        Citigroup
# 34              James Quincey                        Coca-Cola
# 35        Michael J. Cavanagh                          Comcast
# 36           Thomas Gottstein                    Credit Suisse
# 37              Ola Källenius                       Daimler AG
# 38               Michael Dell                             Dell
# 39                 Ed Bastian                  Delta Air Lines
# 40           Christian Sewing                    Deutsche Bank
# 41               Tobias Meyer                        DHL Group
# 42            Edward D. Breen             Dow Chemical Company
# 43                Devin Wenig                             eBay
# 44               Börje Ekholm                         Ericsson
# 45               Darren Woods                       ExxonMobil
# 46           Carmine Di Sibio                    Ernst & Young
# 47            Mark Zuckerberg                         Facebook
# 48            Raj Subramaniam                            FedEx
# 49          Sergio Marchionne                             Fiat
# 50            Abigail Johnson             Fidelity Investments
# 51              James Hackett                             Ford
# 52                  Terry Gou                          Foxconn
# 53            Lachlan Murdoch                  Fox Corporation
# 54                 Ryan Cohen                         GameStop
# 55            Phebe Novakovic                 General Dynamics
# 56       H. Lawrence Culp Jr.                 General Electric
# 57              Mary T. Barra                   General Motors
# 58              Emma Walmsley                  GlaxoSmithKline
# 59           David M. Solomon                    Goldman Sachs
# 60              Sundar Pichai                           Google
# 61              C Vijayakumar                 HCL Technologies
# 62               Antonio Neri       Hewlett Packard Enterprise
# 63            Darius Adamczyk                        Honeywell
# 64                 Noel Quinn                             HSBC
# 65             Arvind Krishna                              IBM
# 66               Salil Parekh                          Infosys
# 67                 Lip-Bu Tan                            Intel
# 68                James Dimon                  JP Morgan Chase
# 69              Pieter Elbers                              KLM
# 70            Charles G. Koch                  Koch Industries
# 71            Marillyn Hewson                  Lockheed Martin
# 72                 Steve Rowe                  Marks & Spencer
# 73          Chris Kempczinski                       McDonald's
# 74              Bob Sternfels               McKinsey & Company
# 75        Steven A. Kandarian                          MetLife
# 76               Isaac Larian                MGA Entertainment
# 77              Satya Nadella                        Microsoft
# 78            James P. Gorman                   Morgan Stanley
# 79        Michael J. Cavanagh                     NBCUniversal
# 80       Robert James Thomson                        News Corp
# 81              Mark Thompson           New York Times Company
# 82                Mark Parker                             Nike
# 83             Pekka Lundmark                            Nokia
# 84          Vasant Narasimhan                         Novartis
# 85          Tatsumi Kimishima                         Nintendo
# 86                 Safra Catz               Oracle Corporation
# 87             Ramon Laguarta                          PepsiCo
# 88              Albert Bourla                           Pfizer
# 89            David S. Taylor                 Procter & Gamble
# 90            John Strangfeld             Prudential Financial
# 91                John Mullen                           Qantas
# 92                Anil Ambani                   Reliance Group
# 93              Mukesh Ambani              Reliance Industries
# 94                Luca de Meo                          Renault
# 95             David I. McKay             Royal Bank of Canada
# 96                Ross McEwan           Royal Bank of Scotland
# 97                 Wael Sawan                Royal Dutch Shell
# 98            Michael O'Leary                          Ryanair
# 99        Douglas L. Peterson                       S&P Global
# 100              Oh-Hyun Kwon                          Samsung
# 101           Christian Klein                              SAP
# 102  Herbert Fisk Johnson III                       SC Johnson
# 103      Jean-Pascal Tricoire               Schneider Electric
# 104            Peter Harrison                        Schroders
# 105           Chua Sock Koong                          Singtel
# 106             Masayoshi Son                         SoftBank
# 107               Tony Aquila                  Solera Holdings
# 108                 Elon Musk                           SpaceX
# 109          Robert E. Jordan               Southwest Airlines
# 110        J. Clifford Hudson                Sonic Corporation
# 111              Brian Niccol                        Starbucks
# 112              Raymond Kwok          Sun Hung Kai Properties
# 113     William H. Rogers Jr.                   SunTrust Banks
# 114             Brian Cornell               Target Corporation
# 115         Rajesh Gopinathan        Tata Consultancy Services
# 116              Li Dongsheng                  TCL Corporation
# 117                 Andy Penn                          Telstra
# 118                Dave Lewis                            Tesco
# 119                 Elon Musk                            Tesla
# 120         Alan D. Schnitzer          The Travelers Companies
# 121               Akio Toyoda                           Toyota
# 122               Scott Kirby                  United Airlines
# 123            Brian Thompson                 UnitedHealthcare
# 124              Ralph Hamers                              UBS
# 125             Hans Vestberg           Verizon Communications
# 126             Robert Bakish                        ViacomCBS
# 127            Ryan McInerney                        Visa Inc.
# 128            Vittorio Colao                         Vodafone
# 129             Herbert Diess                 Volkswagen Group
# 130               Robert Iger              Walt Disney Company
# 131           Stefano Pessina         Walgreens Boots Alliance
# 132             Doug McMillon                          Walmart
# 133               Ann Sarnoff                  Warner Brothers
# 134               Jason Kilar                      WarnerMedia
# 135            Charles Scharf                      Wells Fargo
# 136               John Mackey               Whole Foods Market
# 137               Rich Barton                     Zillow Group
#
#                    clean_name                 born _merge
# 0                 Julie Sweet                  NaT   both
# 1        Kumar Mangalam Birla  1967-06-14 00:00:00   both
# 2            Shantanu Narayen  1963-05-27 00:00:00   both
# 3             Guillaume Faury  1968-02-22 00:00:00   both
# 4                    Eddie Wu                  NaT   both
# 5                  Andy Jassy  1968-01-13 00:00:00   both
# 6                     Lisa Su                  NaT   both
# 7              Stephen Squeri                  NaT   both
# 8           Joseph R. Swedish  1951-05-17 00:00:00   both
# 9                    Tim Cook  1960-11-01 00:00:00   both
# 10              Aditya Mittal  1976-01-22 00:00:00   both
# 11               John Stankey                  NaT   both
# 12           Charles Woodburn  1971-03-11 00:00:00   both
# 13              Tapan Singhel  1966-08-12 00:00:00   both
# 14         Carlos Torres Vila                  NaT   both
# 15             Brian Moynihan                  NaT   both
# 16       C.S. Venkatakrishnan                  NaT   both
# 17             Warren Buffett  1930-08-30 00:00:00   both
# 18                Hubert Joly  1959-08-11 00:00:00   both
# 19        Sunil Bharti Mittal  1957-10-23 00:00:00   both
# 20      Stephen A. Schwarzman  1947-02-14 00:00:00   both
# 21                 Mike Henry                  NaT   both
# 22               Oliver Zipse  1964-02-07 00:00:00   both
# 23              Kelly Ortberg                  NaT   both
# 24                Rich Lesser                  NaT   both
# 25                 Bob Dudley  1955-09-14 00:00:00   both
# 26                   Hock Tan                  NaT   both
# 27            Denise Morrison  1954-01-13 00:00:00   both
# 28          Mark Shuttleworth  1973-09-18 00:00:00   both
# 29           Richard Fairbank  1950-09-18 00:00:00   both
# 30                Jim Umpleby                  NaT   both
# 31             Evan Greenberg  1955-04-01 00:00:00   both
# 32              Chuck Robbins                  NaT   both
# 33                Jane Fraser                  NaT   both
# 34              James Quincey  1965-01-08 00:00:00   both
# 35        Michael J. Cavanagh  1966-01-03 00:00:00   both
# 36           Thomas Gottstein                  NaT   both
# 37              Ola Källenius  1969-06-11 00:00:00   both
# 38               Michael Dell  1965-02-23 00:00:00   both
# 39                 Ed Bastian  1957-06-06 00:00:00   both
# 40           Christian Sewing  1970-04-24 00:00:00   both
# 41               Tobias Meyer                  NaT   both
# 42            Edward D. Breen                  NaT   both
# 43                Devin Wenig                  NaT   both
# 44               Börje Ekholm                  NaT   both
# 45               Darren Woods  1965-12-16 00:00:00   both
# 46           Carmine Di Sibio  1963-03-23 00:00:00   both
# 47            Mark Zuckerberg  1984-05-14 00:00:00   both
# 48            Raj Subramaniam  1967-09-14 00:00:00   both
# 49          Sergio Marchionne                  NaT   both
# 50            Abigail Johnson  1961-12-19 00:00:00   both
# 51              James Hackett                  NaT   both
# 52                  Terry Gou  1950-10-18 00:00:00   both
# 53            Lachlan Murdoch  1971-09-08 00:00:00   both
# 54                 Ryan Cohen                  NaT   both
# 55            Phebe Novakovic                  NaT   both
# 56       H. Lawrence Culp Jr.                  NaT   both
# 57              Mary T. Barra  1961-12-24 00:00:00   both
# 58              Emma Walmsley                  NaT   both
# 59           David M. Solomon  1962-01-17 00:00:00   both
# 60              Sundar Pichai  1972-06-10 00:00:00   both
# 61              C Vijayakumar                  NaT   both
# 62               Antonio Neri  1576-02-29 00:00:00   both
# 63            Darius Adamczyk  1966-02-08 00:00:00   both
# 64                 Noel Quinn                  NaT   both
# 65             Arvind Krishna  1962-11-23 00:00:00   both
# 66               Salil Parekh  1964-06-05 00:00:00   both
# 67                 Lip-Bu Tan  1959-11-12 00:00:00   both
# 68                James Dimon  1956-03-13 00:00:00   both
# 69              Pieter Elbers  1970-05-11 00:00:00   both
# 70            Charles G. Koch  1935-11-01 00:00:00   both
# 71            Marillyn Hewson  1953-12-27 00:00:00   both
# 72                 Steve Rowe  1965-01-19 00:00:00   both
# 73          Chris Kempczinski                  NaT   both
# 74              Bob Sternfels                  NaT   both
# 75        Steven A. Kandarian                  NaT   both
# 76               Isaac Larian  1954-03-28 00:00:00   both
# 77              Satya Nadella  1967-08-19 00:00:00   both
# 78            James P. Gorman  1958-07-14 00:00:00   both
# 79        Michael J. Cavanagh  1966-01-03 00:00:00   both
# 80       Robert James Thomson  1961-03-11 00:00:00   both
# 81              Mark Thompson                  NaT   both
# 82                Mark Parker  1955-10-21 00:00:00   both
# 83             Pekka Lundmark  1963-12-09 00:00:00   both
# 84          Vasant Narasimhan  1976-08-26 00:00:00   both
# 85          Tatsumi Kimishima  1950-04-21 00:00:00   both
# 86                 Safra Catz                  NaT   both
# 87             Ramon Laguarta                  NaT   both
# 88              Albert Bourla  1961-10-21 00:00:00   both
# 89            David S. Taylor  1958-04-20 00:00:00   both
# 90            John Strangfeld                  NaT   both
# 91                John Mullen                  NaT   both
# 92                Anil Ambani  1959-06-04 00:00:00   both
# 93              Mukesh Ambani  1957-04-19 00:00:00   both
# 94                Luca de Meo  1967-06-13 00:00:00   both
# 95             David I. McKay                  NaT   both
# 96                Ross McEwan  1957-07-16 00:00:00   both
# 97                 Wael Sawan                  NaT   both
# 98            Michael O'Leary                  NaT   both
# 99        Douglas L. Peterson                  NaT   both
# 100              Oh-Hyun Kwon                  NaT   both
# 101           Christian Klein  1980-05-04 00:00:00   both
# 102  Herbert Fisk Johnson III  1958-05-19 00:00:00   both
# 103      Jean-Pascal Tricoire                  NaT   both
# 104            Peter Harrison                  NaT   both
# 105           Chua Sock Koong  1957-09-14 00:00:00   both
# 106             Masayoshi Son  1957-08-11 00:00:00   both
# 107               Tony Aquila                  NaT   both
# 108                 Elon Musk  1971-06-28 00:00:00   both
# 109          Robert E. Jordan                  NaT   both
# 110        J. Clifford Hudson                  NaT   both
# 111              Brian Niccol  1974-02-26 00:00:00   both
# 112              Raymond Kwok                  NaT   both
# 113     William H. Rogers Jr.                  NaT   both
# 114             Brian Cornell                  NaT   both
# 115         Rajesh Gopinathan                  NaT   both
# 116              Li Dongsheng                  NaT   both
# 117                 Andy Penn                  NaT   both
# 118                Dave Lewis                  NaT   both
# 119                 Elon Musk  1971-06-28 00:00:00   both
# 120         Alan D. Schnitzer                  NaT   both
# 121               Akio Toyoda  1956-05-03 00:00:00   both
# 122               Scott Kirby  1967-08-13 00:00:00   both
# 123            Brian Thompson                  NaT   both
# 124              Ralph Hamers  1966-05-25 00:00:00   both
# 125             Hans Vestberg  1965-06-23 00:00:00   both
# 126             Robert Bakish  1963-12-14 00:00:00   both
# 127            Ryan McInerney                  NaT   both
# 128            Vittorio Colao  1961-10-03 00:00:00   both
# 129             Herbert Diess  1958-10-24 00:00:00   both
# 130               Robert Iger  1951-02-10 00:00:00   both
# 131           Stefano Pessina  1941-06-04 00:00:00   both
# 132             Doug McMillon  1966-10-17 00:00:00   both
# 133               Ann Sarnoff                  NaT   both
# 134               Jason Kilar  1971-04-26 00:00:00   both
# 135            Charles Scharf  1965-04-24 00:00:00   both
# 136               John Mackey                  NaT   both
# 137               Rich Barton                  NaT   both

# %%
pd.set_option('display.max_rows', 50)
result_df = company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="outer", indicator=True)

result_df[result_df['_merge'] != 'both']
# Out:
# Empty DataFrame
# Columns: [Executive, Company, clean_name, born, _merge]
# Index: []

# %% [markdown]
# We can also do this in SQL (there is no indicator but we can test for NULL):

# %%
duckdb.sql("""
            SELECT Executive, Company, clean_name, born
            FROM company_ceos_df FULL JOIN exec_df ON Executive=clean_name
            WHERE clean_name is null or Company is null
          """)
# Out:
# ┌───────────┬─────────┬────────────┬───────────┐
# │ Executive │ Company │ clean_name │   born    │
# │  varchar  │ varchar │  varchar   │ timestamp │
# ├───────────┴─────────┴────────────┴───────────┤
# │                    0 rows                    │
# └──────────────────────────────────────────────┘

# %% [markdown]
# ## 2.3. Composing Joins
#
# Of course, we can join the results of a join with another table -- representing a *composition*!

# %% [markdown]
# Let's join with company data!

# %%
duckdb.sql("""SELECT Executive, Company, born
            FROM company_ceos_df
            JOIN exec_df ON Executive=replace(name, '_', ' ')
            JOIN company_data_df cd ON Company=cd.name
            WHERE born is not null""")
# Out:
# ┌───────────┬─────────┬───────────┐
# │ Executive │ Company │   born    │
# │  varchar  │ varchar │ timestamp │
# ├───────────┴─────────┴───────────┤
# │             0 rows              │
# └─────────────────────────────────┘

# %% [markdown]
# Hmm, what is wrong here?
#
# Let's switch to the tables saved in DuckDB for these.

# %%
con.sql('SELECT * from company_data')
# Out:
# ┌────────────┬────────────────────────────────────────────────┬────────────────────┬──────────────┬─────────────────────────────────────┬─────────────┬────────────────────────────────────────┬────────────────┬─────────────────────────────────────────────────────────────────┬───────────────────────────┬─────────────────────────┐
# │ Unnamed: 0 │                      name                      │       domain       │ year founded │              industry               │ size range  │                locality                │    country     │                          linkedin url                           │ current employee estimate │ total employee estimate │
# │   int64    │                    varchar                     │      varchar       │    double    │               varchar               │   varchar   │                varchar                 │    varchar     │                             varchar                             │           int64           │          int64          │
# ├────────────┼────────────────────────────────────────────────┼────────────────────┼──────────────┼─────────────────────────────────────┼─────────────┼────────────────────────────────────────┼────────────────┼─────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────────────────────┤
# │    5872184 │ ibm                                            │ ibm.com            │       1911.0 │ information technology and services │ 10001+      │ new york, new york, united states      │ united states  │ linkedin.com/company/ibm                                        │                    274047 │                  716906 │
# │    4425416 │ tata consultancy services                      │ tcs.com            │       1968.0 │ information technology and services │ 10001+      │ bombay, maharashtra, india             │ india          │ linkedin.com/company/tata-consultancy-services                  │                    190771 │                  341369 │
# │      21074 │ accenture                                      │ accenture.com      │       1989.0 │ information technology and services │ 10001+      │ dublin, dublin, ireland                │ ireland        │ linkedin.com/company/accenture                                  │                    190689 │                  455768 │
# │    2309813 │ us army                                        │ goarmy.com         │       1800.0 │ military                            │ 10001+      │ alexandria, virginia, united states    │ united states  │ linkedin.com/company/us-army                                    │                    162163 │                  445958 │
# │    1558607 │ ey                                             │ ey.com             │       1989.0 │ accounting                          │ 10001+      │ london, greater london, united kingdom │ united kingdom │ linkedin.com/company/ernstandyoung                              │                    158363 │                  428960 │
# │    3844889 │ hewlett-packard                                │ hpe.com            │       1939.0 │ information technology and services │ 10001+      │ palo alto, california, united states   │ united states  │ linkedin.com/company/hewlett-packard-enterprise                 │                    127952 │                  412952 │
# │    2959148 │ cognizant technology solutions                 │ cognizant.com      │       1994.0 │ information technology and services │ 10001+      │ teaneck, new jersey, united states     │ united states  │ linkedin.com/company/cognizant                                  │                    122031 │                  210020 │
# │    5944912 │ walmart                                        │ walmartcareers.com │       1962.0 │ retail                              │ 10001+      │ withee, wisconsin, united states       │ united states  │ linkedin.com/company/walmart                                    │                    120753 │                  272827 │
# │    3727010 │ microsoft                                      │ microsoft.com      │       1975.0 │ computer software                   │ 10001+      │ redmond, washington, united states     │ united states  │ linkedin.com/company/microsoft                                  │                    116196 │                  276983 │
# │    3300741 │ at&t                                           │ att.com            │       1876.0 │ telecommunications                  │ 10001+      │ dallas, texas, united states           │ united states  │ linkedin.com/company/at&t                                       │                    115188 │                  269659 │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │       ·    │  ·                                             │    ·               │           ·  │         ·                           │   ·         │  ·                                     │  ·             │             ·                                                   │                        ·  │                      ·  │
# │    4782764 │ jönköpings kommun                              │ jonkoping.se       │         NULL │ government administration           │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/j-nk-pings-kommun                          │                      1118 │                    1964 │
# │    3432133 │ jmc projects india ltd                         │ jmcprojects.com    │       1982.0 │ human resources                     │ 1001 - 5000 │ bombay, maharashtra, india             │ india          │ linkedin.com/company/jmc-projects-india-ltd                     │                      1118 │                    2112 │
# │     910050 │ öbb                                            │ oebb.at            │         NULL │ transportation/trucking/railroad    │ 1001 - 5000 │ wien, vienna, austria                  │ austria        │ linkedin.com/company/obb                                        │                      1118 │                    1546 │
# │    6444131 │ vaillant group                                 │ vaillant-group.com │       1874.0 │ renewables & environment            │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/vaillant                                   │                      1118 │                    2540 │
# │     916799 │ embracon administradora de consórcio ltda.     │ embracon.com.br    │       1988.0 │ financial services                  │ 1001 - 5000 │ santana de parnaíba, sao paulo, brazil │ brazil         │ linkedin.com/company/embracon-administradora-de-cons-rcio-ltda. │                      1118 │                    2240 │
# │    3585785 │ university of chicago booth school of business │ chicagobooth.edu   │       1898.0 │ higher education                    │ 1001 - 5000 │ chicago, illinois, united states       │ united states  │ linkedin.com/company/universityofchicagoboothschoolofbusiness   │                      1118 │                    3220 │
# │    2583172 │ pantaloon retail india ltd                     │ NULL               │         NULL │ retail                              │ 1001 - 5000 │ bombay, maharashtra, india             │ india          │ linkedin.com/company/pantaloon-retail-india-ltd                 │                      1118 │                    4723 │
# │    1406043 │ nv energy                                      │ nvenergy.com       │       1906.0 │ utilities                           │ 1001 - 5000 │ las vegas, nevada, united states       │ united states  │ linkedin.com/company/nv-energy                                  │                      1118 │                    1834 │
# │     955441 │ mining                                         │ muslimbase.com     │         NULL │ mining & metals                     │ 1001 - 5000 │ NULL                                   │ NULL           │ linkedin.com/company/mining                                     │                      1118 │                    1421 │
# │    5571765 │ university of stirling                         │ stir.ac.uk         │       1967.0 │ higher education                    │ 1001 - 5000 │ stirling, stirling, united kingdom     │ united kingdom │ linkedin.com/company/university-of-stirling                     │                      1118 │                    2680 │
# ├────────────┴────────────────────────────────────────────────┴────────────────────┴──────────────┴─────────────────────────────────────┴─────────────┴────────────────────────────────────────┴────────────────┴─────────────────────────────────────────────────────────────────┴───────────────────────────┴─────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                              11 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Notice the case for `name`?

# %%
con.sql("""SELECT Executive, Company, born
            FROM company_ceos
            JOIN executives ON Executive=replace(name, '_', ' ')
            JOIN company_data cd ON lower(Company)=lower(cd.name)
            WHERE born is not null
            ORDER BY Company""")
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Hans Vestberg        │ Verizon Communications   │ 1965-06-23 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 148 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Hmm, there are duplicates!  This is because of fields in the `company_data` table that we don't care about. We can remove the duplicates via `SELECT DISTINCT`.

# %%
con.sql("""SELECT DISTINCT Executive, Company, born
            FROM company_ceos
            JOIN executives ON Executive=replace(name, '_', ' ')
            JOIN company_data cd ON lower(Company)=lower(cd.name)
            WHERE born is not null
            ORDER BY Company""")
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Charles Woodburn     │ BAE Systems              │ 1971-03-11 00:00:00 │
# │ Oliver Zipse         │ BMW                      │ 1964-02-07 00:00:00 │
# │ Bob Dudley           │ BP                       │ 1955-09-14 00:00:00 │
# │ Warren Buffett       │ Berkshire Hathaway       │ 1930-08-30 00:00:00 │
# │ Hubert Joly          │ Best Buy                 │ 1959-08-11 00:00:00 │
# │     ·                │   ·                      │          ·          │
# │     ·                │   ·                      │          ·          │
# │     ·                │   ·                      │          ·          │
# │ Elon Musk            │ Tesla                    │ 1971-06-28 00:00:00 │
# │ Akio Toyoda          │ Toyota                   │ 1956-05-03 00:00:00 │
# │ Ralph Hamers         │ UBS                      │ 1966-05-25 00:00:00 │
# │ Scott Kirby          │ United Airlines          │ 1967-08-13 00:00:00 │
# │ Hans Vestberg        │ Verizon Communications   │ 1965-06-23 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 65 rows (20 shown)                                          3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Can we do all of this in Pandas? Of course!
#
# First, we need to lowercase the company names.

# %%
company_ceos_df['company_lc'] = company_ceos_df['Company'].apply(lambda x: x.lower())

# %% [markdown]
# Notice this is slower than DuckDB?

# %%
company_ceos_df.merge(exec_df.dropna(),
                      left_on=['Executive'],
                      right_on=['clean_name']).\
                      merge(company_data_df,
                            left_on='company_lc',
                            right_on='name')[['Executive','Company','born']].drop_duplicates().sort_values('Company')
# Out:
#                 Executive                   Company                 born
# 0    Kumar Mangalam Birla        Aditya Birla Group  1967-06-14 00:00:00
# 1         Guillaume Faury                    Airbus  1968-02-22 00:00:00
# 3              Andy Jassy                    Amazon  1968-01-13 00:00:00
# 5       Joseph R. Swedish                    Anthem  1951-05-17 00:00:00
# 6                Tim Cook                     Apple  1960-11-01 00:00:00
# ..                    ...                       ...                  ...
# 129        Vittorio Colao                  Vodafone  1961-10-03 00:00:00
# 132       Stefano Pessina  Walgreens Boots Alliance  1941-06-04 00:00:00
# 133         Doug McMillon                   Walmart  1966-10-17 00:00:00
# 131           Robert Iger       Walt Disney Company  1951-02-10 00:00:00
# 135        Charles Scharf               Wells Fargo  1965-04-24 00:00:00
#
# [65 rows x 3 columns]

# %% [markdown]
# ## Section 2 Exercises

# %% [markdown]
# Hmm, there seem to be quite a few Roberts and Bobs. (Maybe also Roberta?)
#
# Using either Pandas operations like `merge` and the various bracket notations (but **not** the `loc`/`iloc` commands if you know these): write a query that takes the `company_ceos_df` and returns all companies that are overseen by someone with names `Bob`, `Robert`, or `Roberta`.

# %% [markdown]
# First, define a function that *robustly* does this:

# %%
def bob(name: str) -> bool:
  longName = name.split() # TODO: change this to get first name!
  first_name = longName[0].lower()
  return first_name == 'bob' or first_name == 'robert' or first_name == 'roberta' # TODO: change this!

# %%
from dill.source import getsource
grader.grade('bob_test', getsource(bob))
# Out:
# Correct! You earned 3/3 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.

# %% [markdown]
# Now *select a subset of the rows* that have Bob/etc. using the function `bob` and the `apply` function.

# %%
bob_co_df = company_ceos_df[company_ceos_df['Executive'].apply(bob)] # TODO
bob_co_df
# Out:
#                  Company             Executive  \
# 25                    BP            Bob Dudley
# 74    McKinsey & Company         Bob Sternfels
# 80             News Corp  Robert James Thomson
# 109   Southwest Airlines      Robert E. Jordan
# 126            ViacomCBS         Robert Bakish
# 130  Walt Disney Company           Robert Iger
#
#                               Title Since  \
# 25        Group chief executive[25]  2010
# 74      Global managing partner[68]  2021
# 80                          CEO[73]  2013
# 109  President, CEO, vice-chair[99]  2022
# 126          President and CEO[117]  2019
# 130                        CEO[121]  2022
#
#                                                  Notes     Updated  \
# 25                               Previously led TNK-BP  2017-11-15
# 74                             Succeeded Kevin Sneader  2023-12-08
# 80   Previously managing editor of The Wall Street ...  2017-11-12
# 109  Replaced former CEO Gary C. Kelly; joined Sout...  2023-02-21
# 126                  Has been with the firm since 1997  2020-03-02
# 130  Previously led Disney Parks, Experiences and P...  2020-03-02
#
#               company_lc
# 25                    bp
# 74    mckinsey & company
# 80             news corp
# 109   southwest airlines
# 126            viacomcbs
# 130  walt disney company

# %%
grader.grade(test_case_id='bobs_your_uncle_or_aunt', answer=bob_co_df)
# Out:
# Correct! You earned 2/2 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.
